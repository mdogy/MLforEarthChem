# %%
import pandas as pd

# %%
URL = r"C:\Users\natasha\Downloads\earthchem_download_62420.xlsx"

# %%
Sample_id = pd.read_excel(URL, header = None)

# %%
#Sample_id = Sample_id.reset_index(drop=True, inplace=True)

# %%
Sample_id[:10]
# Out:
#                                                   0        1            2   \
# 0  EarthChem Download: Friday, Jul. 17, 2020 6:27...      NaN          NaN
# 1                                                NaN      NaN          NaN
# 2                                   Search Criteria:      NaN          NaN
# 3                                          Materials  Igneous          NaN
# 4                                                NaN      NaN          NaN
# 5                                          SAMPLE ID     IGSN       SOURCE
# 6                                   KAK19XX-006-007F      NaN  EARTHCHEMDB
# 7                                   KAK19XX-006-007F      NaN  EARTHCHEMDB
# 8                                   KAK19XX-006-007F      NaN  EARTHCHEMDB
# 9                                   KAK19XX-006-007F      NaN  EARTHCHEMDB
#
#                               3   \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# ...

# %%
Sample_id = Sample_id.drop([0,1,2,3,4])

# %%
Sample_id.head()
# Out:
#                  0     1            2                              3   \
# 5         SAMPLE ID  IGSN       SOURCE                            DOI
# 6  KAK19XX-006-007F   NaN  EARTHCHEMDB  10.1016/S0024-4937(87)80005-1
# 7  KAK19XX-006-007F   NaN  EARTHCHEMDB  10.1016/S0024-4937(87)80005-1
# 8  KAK19XX-006-007F   NaN  EARTHCHEMDB  10.1016/S0024-4937(87)80005-1
# 9  KAK19XX-006-007F   NaN  EARTHCHEMDB  10.1016/S0024-4937(87)80005-1
#
#                                                   4        5   \
# 5                                              TITLE  JOURNAL
# 6  PETROLOGY AND GEOCHRONOLOGY OF VOLCANIC ROCKS ...   LITHOS
# 7  PETROLOGY AND GEOCHRONOLOGY OF VOLCANIC ROCKS ...   LITHOS
# 8  PETROLOGY AND GEOCHRONOLOGY OF VOLCANIC ROCKS ...   LITHOS
# 9  PETROLOGY AND GEOCHRONOLOGY OF VOLCANIC ROCKS ...   LITHOS
#
#                                         6              7         8   \
# 5                                   AUTHOR  EXPEDITION ID  LATITUDE
# ...

# %%
# Specimen_id = Specimen_id.rename(columns=Specimen_id.iloc[0]).drop(Specimen_id.index[0])
Sample_id = Sample_id.reset_index(drop = True)

# %%
Sample_id.head()
# Out:
#                  0     1            2                              3   \
# 0         SAMPLE ID  IGSN       SOURCE                            DOI
# 1  KAK19XX-006-007F   NaN  EARTHCHEMDB  10.1016/S0024-4937(87)80005-1
# 2  KAK19XX-006-007F   NaN  EARTHCHEMDB  10.1016/S0024-4937(87)80005-1
# 3  KAK19XX-006-007F   NaN  EARTHCHEMDB  10.1016/S0024-4937(87)80005-1
# 4  KAK19XX-006-007F   NaN  EARTHCHEMDB  10.1016/S0024-4937(87)80005-1
#
#                                                   4        5   \
# 0                                              TITLE  JOURNAL
# 1  PETROLOGY AND GEOCHRONOLOGY OF VOLCANIC ROCKS ...   LITHOS
# 2  PETROLOGY AND GEOCHRONOLOGY OF VOLCANIC ROCKS ...   LITHOS
# 3  PETROLOGY AND GEOCHRONOLOGY OF VOLCANIC ROCKS ...   LITHOS
# 4  PETROLOGY AND GEOCHRONOLOGY OF VOLCANIC ROCKS ...   LITHOS
#
#                                         6              7         8   \
# 0                                   AUTHOR  EXPEDITION ID  LATITUDE
# ...
